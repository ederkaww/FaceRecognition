# %% [markdown]
# ## Import

# %%
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import cv2

# %matplotlib inline

# %% [markdown]
# ## Przygotowanie danych do uczenia

# %%
train_dir = 'anna_unknown_dataset/anna_unknown_dataset/train'
validation_dir = 'anna_unknown_dataset/anna_unknown_dataset/val'
test_dir = 'anna_unknown_dataset/anna_unknown_dataset/test'

train = ImageDataGenerator(rescale=1/255)
validation = ImageDataGenerator(rescale=1/255)

train_dataset = train.flow_from_directory(
        train_dir, 
        target_size=(200, 200),
        batch_size=20,
        shuffle=True,
        class_mode='binary')

validation_dataset = validation.flow_from_directory(
        validation_dir,
        target_size=(200, 200),
        batch_size=20,
        shuffle=True,
        class_mode='binary')
# Out:
# Found 2100 images belonging to 2 classes.
# Found 300 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'Anna': 0, 'Unknown': 1}

# %%
img, label = train_dataset.next()
print(img.shape)
plt.imshow(img[0])
plt.show()
# Out:
# (20, 200, 200, 3)

# %% [markdown]
# ## Model sieci

# %%
model = Sequential()

# Convolution & pooling - First convolution layer
model.add(Conv2D(16, (3, 3),
                      input_shape = (200,200,3),
                      activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

# Convolution & pooling - Second convolution layer (same as first layer)
model.add(Conv2D(32, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))


# Convolution & pooling - Third convolution layer
model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size = (2, 2)))

# Flattening
model.add(Flatten())

# Full connection
model.add(Dense(512, activation = 'relu')) 
model.add(Dense(1, activation = 'sigmoid'))

# Compiling the CNN
model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 198, 198, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 99, 99, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 97, 97, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 33856)             0
#
#  dense (Dense)               (None, 512)               17334784
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 17,358,881
# Trainable params: 17,358,881
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Uczenie

# %%
hist = model.fit(train_dataset, epochs = 15, validation_data = validation_dataset)
# Out:
# Epoch 1/15
# 105/105 [==============================] - 75s 706ms/step - loss: 0.6030 - accuracy: 0.7014 - val_loss: 0.1347 - val_accuracy: 0.9500
# Epoch 2/15
# 105/105 [==============================] - 73s 692ms/step - loss: 0.2445 - accuracy: 0.9029 - val_loss: 0.0863 - val_accuracy: 0.9733
# Epoch 3/15
# 105/105 [==============================] - 73s 696ms/step - loss: 0.1721 - accuracy: 0.9310 - val_loss: 0.0442 - val_accuracy: 0.9867
# Epoch 4/15
# 105/105 [==============================] - 74s 701ms/step - loss: 0.0985 - accuracy: 0.9610 - val_loss: 0.0506 - val_accuracy: 0.9767
# Epoch 5/15
# 105/105 [==============================] - 74s 700ms/step - loss: 0.0483 - accuracy: 0.9814 - val_loss: 0.0159 - val_accuracy: 0.9967
# Epoch 6/15
# 105/105 [==============================] - 74s 702ms/step - loss: 0.0492 - accuracy: 0.9824 - val_loss: 0.0296 - val_accuracy: 0.9967
# Epoch 7/15
# 105/105 [==============================] - 74s 703ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.0428 - val_accuracy: 0.9767
# Epoch 8/15
# 105/105 [==============================] - 74s 703ms/step - loss: 0.0496 - accuracy: 0.9814 - val_loss: 0.0367 - val_accuracy: 0.9867
# Epoch 9/15
# 105/105 [==============================] - 74s 702ms/step - loss: 0.0072 - accuracy: 0.9990 - val_loss: 0.0062 - val_accuracy: 0.9967
# Epoch 10/15
# 105/105 [==============================] - 74s 704ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0053 - val_accuracy: 1.0000
# Epoch 11/15
# 105/105 [==============================] - 73s 698ms/step - loss: 6.0223e-04 - accuracy: 1.0000 - val_loss: 0.0069 - val_accuracy: 0.9967
# Epoch 12/15
# 105/105 [==============================] - 74s 700ms/step - loss: 2.1746e-04 - accuracy: 1.0000 - val_loss: 0.0040 - val_accuracy: 1.0000
# Epoch 13/15
# 105/105 [==============================] - 73s 695ms/step - loss: 1.4542e-04 - accuracy: 1.0000 - val_loss: 0.0035 - val_accuracy: 1.0000
# Epoch 14/15
# 105/105 [==============================] - 73s 688ms/step - loss: 1.0542e-04 - accuracy: 1.0000 - val_loss: 0.0032 - val_accuracy: 1.0000
# Epoch 15/15
# 105/105 [==============================] - 73s 694ms/step - loss: 7.6164e-05 - accuracy: 1.0000 - val_loss: 0.0037 - val_accuracy: 1.0000

# %% [markdown]
# ## Parametry

# %%
print(hist.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.figure(1, figsize = (15, 5))
plt.subplot(1,2,1)
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot( hist.history["loss"], label = "Training Loss")
plt.plot( hist.history["val_loss"], label = "Validation Loss")
plt.grid(True)
plt.legend()

plt.subplot(1,2,2)
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot( hist.history["accuracy"], label = "Training Accuracy")
plt.plot( hist.history["val_accuracy"], label = "Validation Accuracy")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## Predicting

# %%
test = ImageDataGenerator(rescale = 1./255)
test_dataset = test.flow_from_directory(test_dir,
                                        target_size = (200,200),
                                        batch_size = 3,
                                        class_mode = None,
                                       shuffle = False)


predictions = model.predict_generator(test_dataset)
predictions[predictions <= 0.5] = 0
predictions[predictions > 0.5] = 1
# Out:
# Found 600 images belonging to 2 classes.
# C:\Users\domin\AppData\Local\Temp/ipykernel_16896/4197648601.py:10: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   predictions = model.predict_generator(test_dataset)

# %% [markdown]
# ## Confusion matrix

# %%
cm = pd.DataFrame(data=confusion_matrix(test_dataset.classes, predictions, labels=[1, 0]),
                  index=["Actual Unknown", "Actual Anna"],
                  columns=["Predicted Unknown", "Predicted Anna"])
cm
# Out:
#                 Predicted Unknown  Predicted Anna
# Actual Unknown                297               3
# Actual Anna                     4             296

# %% [markdown]
# ## Saving the model

# %%
model.save('anna_unknown.h5')
